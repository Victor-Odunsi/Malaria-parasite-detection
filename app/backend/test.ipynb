# %%
from pathlib import Path

from config import settings

if isinstance(settings.model_dir, Path):
    print("Model directory is a valid Path object.")
# Out:
# Model directory is a valid Path object.

# %%
import config
print(config.__file__)

# %%
pip install huggingface-hub
